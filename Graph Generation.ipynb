# %%
"""matplotlib block"""
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import scraper as scp
import generate_graphs as grph
from utils import get_user_name, init_folders
from config import SRC_API_URL

import pandas as pd
import requests

from datetime import datetime

# %%
init_folders()

# %%
lvl = scp.get_levels(['PT'], local_load=False)
cat = scp.get_categories(['PT'], local_load=False)
#ldb = scp.get_leaderboards()
# Out:
# Got 28 results
# Got 9 results

# %%
pt_ce_lvl = scp.get_levels(['PT', 'PT_CE', 'PT_DEMO'], local_load=False)
pt_ce_cat = scp.get_categories(['PT', 'PT_CE', 'PT_DEMO'], local_load=False)

pt_ce_runs = scp.get_all_runs(['PT', 'PT_CE', 'PT_DEMO'], local_load=False)
# Out:
# Got 28 results
# Got 19 results
# Got 5 results
# Got 9 results
# Got 7 results
# Got 5 results
# Got 2800 results{"status":420,"message":"You have reached the maximum allowed number of requests per minute. Calm down, buddy.","links":[{"rel":"support","uri":"irc:\/\/speedrunslive.com#speedrun.com"},{"rel":"report-issues","uri":"https:\/\/github.com\/speedruncom\/api\/issues"}]}
# Got 4000 results{"status":420,"message":"You have reached the maximum allowed number of requests per minute. Calm down, buddy.","links":[{"rel":"support","uri":"irc:\/\/speedrunslive.com#speedrun.com"},{"rel":"report-issues","uri":"https:\/\/github.com\/speedruncom\/api\/issues"}]}
# Got 4692 results
# Got 55 resultsFetched new user TheGladHatter_
#
# Got 232 resultsFetched new user Pr3tz31
# Fetched new user highTrolla
# Fetched new user Smiley_the_guy
# Fetched new user SoySocks
# Fetched new user Epaikra
# Fetched new user LionyLies
# Fetched new user FakePeppino
# {'status': 420, 'message': 'You have reached the maximum allowed number of requests per minute. Calm down, buddy.', 'links': [{'rel': 'support', 'uri': 'irc://speedrunslive.com#speedrun.com'}, {'rel': 'report-issues', 'uri': 'https://github.com/speedruncom/api/issues'}]}
# Fetched new user StrollinThruGames
# Fetched new user AAlex
# Fetched new user speed_orion
# Fetched new user absurdstar
# Fetched new user ElMagoJojo
# Fetched new user DoubleTwelve
# Fetched new user FilipGamer717
# Fetched new user ApplesMustRun
# Fetched new user myrmyxo
# Fetched new user malcigamer
# Fetched new user pearson12
# Fetched new user Theredhedgehog
# Fetched new user Scepter
# Fetched new user Hayge
# Fetched new user Bondorak
# Fetched new user SpongeySauce69
# Fetched new user Varis
# Fetched new user The_GmaerYT
# Fetched new user SerOelix
# Fetched new user WARU
# Fetched new user FrozenHawk
# Fetched new user Clay57
# Fetched new user Toasty_Mann
# Fetched new user DeterminedHugo
# Fetched new user eltipomisfortune671
# Fetched new user runusstuff
# Fetched new user dezookits
# Fetched new user SomeLoserGuy
# Fetched new user CIABBATTA
# Fetched new user banana_man826773
# Fetched new user B4ngFargl3
# Fetched new user Vitalemon
# Fetched new user Mr_Cake75
# {'status': 420, 'message': 'You have reached the maximum allowed number of requests per minute. Calm down, buddy.', 'links': [{'rel': 'support', 'uri': 'irc://speedrunslive.com#speedrun.com'}, {'rel': 'report-issues', 'uri': 'https://github.com/speedruncom/api/issues'}]}
# Fetched new user kiwisidk
# Fetched new user Spongmen223
# Fetched new user Knightofda23
# Fetched new user 3du4rd0999
# Fetched new user CatGamer521
# Fetched new user Taco_Stuff12
# Fetched new user felipemario22yt
# Fetched new user snaic
# Fetched new user Glitchedblood
# Fetched new user Superjack24a
# Fetched new user Odin_Hebert_YT
# Fetched new user rhino_1
# Fetched new user vasekbrothoodgaming
# Fetched new user Dr_Hex
# Fetched new user SubscribeSandwiches
# Fetched new user Horns52
# Fetched new user Kloom555

# %%
grph.export_joined_runs_csv(refresh=True)

# %%
x = grph.get_verifier_stats()
x
# Out:
# Fetched new user HandyBoy
# Fetched new user Hoettilla
#            id     verifier_name
# examiner
# j922yyv8  969          stackman
# 68wrdwzj  674      SoaringSloth
# v81v7558  562             Vicas
# x7q7vor8  409           LOSTMAN
# j5qz5knj  399             Terpo
# 5j53ozgx  356        XBC30EP450
# v8lzke7x  242           LeKukie
# jp6dkw28  204            HatBun
# xkoyp9k8  197      impossablank
# y8dql19j  117          HandyBoy
# jn9wkldx  108         slumbreon
# v8ld9rrj   99           Crayola
# xz0d0ke8   90  FledglingCoolman
# 8q62zddj   72             Sturg
# 48gpl1p8   66          WuSeagal
# xko3z398   31       some_dingus
# kjpz544x   26           Cerbera
# xz9o67n8   24           Jomaswe
# jnpelz28   20      TheRealYoshi
# 8rl0log8    9  GarbageManThe4th
# zx70eo0j    8        elliejelli
# zxzl73e8    6         Hoettilla

# %%
levels = pd.read_parquet(scp.DATA_PATH / "PT_levels.parquet")
levels
# Out:
#           id                                        name  \
# 0   n93rnlr9                                    Tutorial
# 1   z98xz51d                            F1 - John Gutter
# 2   rdnylx69                             F1 - Pizzascape
# 3   ldyo5k79                         F1 - Ancient Cheese
# 4   gdrz86k9                     F1 - Bloodsauce Dungeon
# 5   nwl8y4gd                         F2 - Oregano Desert
# 6   yweojx49                              F2 - Wasteyard
# 7   69z1qe4w                               F2 - Fun Farm
# 8   r9gpjq29                        F2 - Fastfood Saloon
# 9   o9xjzr7d                             F3 - Crust Cove
# 10  495erx49                           F3 - Gnome Forest
# 11  rdqe34gd                                   F3 - GOLF
# 12  5d7geqed                            F3 - Deep-Dish 9
# 13  kwj28419                           F4 - The Pig City
# 14  owore43w                               F4 - Oh Shit!
# 15  xd1n3lyw                       F4 - Peppibot Factory
# 16  ewplz44d  F4 - Refrigerator-Refrigerador-Freezerator
# 17  y9mnr40d                             F5 - Pizzascare
# 18  5wk3n4x9                     F5 - Don't Make a Sound
# 19  592y8e6w                                    F5 - WAR
# 20  29vqlnxd           F5 - The Crumbling Tower of Pizza
# 21  xd4lyg89                                   Pepperman
# 22  xd0826j9                               The Vigilante
# 23  rw6zl56d                                   The Noise
# 24  n93rnzr9                                Fake Peppino
# 25  z98xz41d                                   Pizzaface
# 26  z98v637w                        Secrets of the World
# 27  n935717w                                Tricky Treat
#
#                                               weblink  \
# 0       https://www.speedrun.com/pizza_tower/Tutorial
# 1   https://www.speedrun.com/pizza_tower/F1_-_John...
# 2   https://www.speedrun.com/pizza_tower/F1_-_Pizz...
# 3   https://www.speedrun.com/pizza_tower/F1_-_Anci...
# 4   https://www.speedrun.com/pizza_tower/F1_-_Bloo...
# 5   https://www.speedrun.com/pizza_tower/F2_-_Oreg...
# 6   https://www.speedrun.com/pizza_tower/F2_-_Wast...
# 7   https://www.speedrun.com/pizza_tower/F2_-_Fun_...
# 8   https://www.speedrun.com/pizza_tower/F2_-_Fast...
# 9   https://www.speedrun.com/pizza_tower/F3_-_Crus...
# 10  https://www.speedrun.com/pizza_tower/F3_-_Gnom...
# 11     https://www.speedrun.com/pizza_tower/F3_-_GOLF
# 12  https://www.speedrun.com/pizza_tower/F3_-_Deep...
# 13  https://www.speedrun.com/pizza_tower/F4_-_The_...
# 14  https://www.speedrun.com/pizza_tower/F4_-_Oh_Shit
# 15  https://www.speedrun.com/pizza_tower/F4_-_Pepp...
# 16  https://www.speedrun.com/pizza_tower/F4_-_Refr...
# 17  https://www.speedrun.com/pizza_tower/F5_-_Pizz...
# 18  https://www.speedrun.com/pizza_tower/F5_-_Dont...
# 19      https://www.speedrun.com/pizza_tower/F5_-_WAR
# 20  https://www.speedrun.com/pizza_tower/F5_-_The_...
# 21     https://www.speedrun.com/pizza_tower/Pepperman
# 22  https://www.speedrun.com/pizza_tower/The_Vigil...
# 23     https://www.speedrun.com/pizza_tower/The_Noise
# 24  https://www.speedrun.com/pizza_tower/Fake_Peppino
# 25     https://www.speedrun.com/pizza_tower/Pizzaface
# 26  https://www.speedrun.com/pizza_tower/secrets-o...
# 27  https://www.speedrun.com/pizza_tower/tricky-treat
#
#                                                 rules  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20  For The Crumbling Tower of Pizza:\r\n* You mus...
# 21  For Pepperman:\r\n* Time ends upon landing the...
# 22  For Vigilante\r\n* Time ends upon shooting on ...
# 23  For The Noise:\r\n* Time ends upon triggering ...
# 24  For Fake peppino:\r\n* Time ends on the up inp...
# 25  For Pizzaface:\r\n* Time ends as you land the ...
# 26
# 27  - Time for Tricky Treat starts when the room b...
#
#                                                 links            short_name
# 0   [{'rel': 'self', 'uri': 'https://www.speedrun....              Tutorial
# 1   [{'rel': 'self', 'uri': 'https://www.speedrun....           John Gutter
# 2   [{'rel': 'self', 'uri': 'https://www.speedrun....            Pizzascape
# 3   [{'rel': 'self', 'uri': 'https://www.speedrun....        Ancient Cheese
# 4   [{'rel': 'self', 'uri': 'https://www.speedrun....    Bloodsauce Dungeon
# 5   [{'rel': 'self', 'uri': 'https://www.speedrun....        Oregano Desert
# 6   [{'rel': 'self', 'uri': 'https://www.speedrun....             Wasteyard
# 7   [{'rel': 'self', 'uri': 'https://www.speedrun....              Fun Farm
# 8   [{'rel': 'self', 'uri': 'https://www.speedrun....       Fastfood Saloon
# 9   [{'rel': 'self', 'uri': 'https://www.speedrun....            Crust Cove
# 10  [{'rel': 'self', 'uri': 'https://www.speedrun....          Gnome Forest
# 11  [{'rel': 'self', 'uri': 'https://www.speedrun....                  GOLF
# 12  [{'rel': 'self', 'uri': 'https://www.speedrun....           Deep-Dish 9
# 13  [{'rel': 'self', 'uri': 'https://www.speedrun....          The Pig City
# 14  [{'rel': 'self', 'uri': 'https://www.speedrun....              Oh Shit!
# 15  [{'rel': 'self', 'uri': 'https://www.speedrun....      Peppibot Factory
# 16  [{'rel': 'self', 'uri': 'https://www.speedrun....           Freezerator
# 17  [{'rel': 'self', 'uri': 'https://www.speedrun....            Pizzascare
# 18  [{'rel': 'self', 'uri': 'https://www.speedrun....                  DMaS
# 19  [{'rel': 'self', 'uri': 'https://www.speedrun....                   WAR
# 20  [{'rel': 'self', 'uri': 'https://www.speedrun....       Crumbling Tower
# 21  [{'rel': 'self', 'uri': 'https://www.speedrun....             Pepperman
# 22  [{'rel': 'self', 'uri': 'https://www.speedrun....         The Vigilante
# 23  [{'rel': 'self', 'uri': 'https://www.speedrun....             The Noise
# 24  [{'rel': 'self', 'uri': 'https://www.speedrun....          Fake Peppino
# 25  [{'rel': 'self', 'uri': 'https://www.speedrun....             Pizzaface
# 26  [{'rel': 'self', 'uri': 'https://www.speedrun....  Secrets of the World
# 27  [{'rel': 'self', 'uri': 'https://www.speedrun....          Tricky Treat

# %%
z = grph.plot_runs_per_week()

# %%
il_g = grph.plot_il_graph()

# %%
ilc = grph.get_il_counts()
ilc.sort_values("Any%")
# Out:
# Categories            100%  All Toppins   Any%
# short_name
# Secrets of the World  12.0          0.0   13.0
# Oh Shit!              10.0         11.0   23.0
# Crust Cove            16.0         14.0   26.0
# Deep-Dish 9            9.0         21.0   28.0
# Tricky Treat          18.0          0.0   29.0
# Peppibot Factory      16.0         25.0   31.0
# Freezerator            8.0         28.0   31.0
# Wasteyard             24.0         17.0   33.0
# Pizzascare            25.0         33.0   34.0
# Fastfood Saloon       13.0         14.0   35.0
# Gnome Forest          21.0         23.0   35.0
# Fake Peppino           0.0          0.0   36.0
# Fun Farm              16.0         20.0   37.0
# The Vigilante          0.0          0.0   39.0
# Bloodsauce Dungeon    22.0         30.0   43.0
# DMaS                  17.0         26.0   45.0
# Pizzaface              0.0          0.0   46.0
# Oregano Desert        20.0         27.0   46.0
# The Noise              0.0          0.0   50.0
# The Pig City           8.0         15.0   52.0
# Crumbling Tower       14.0          0.0   52.0
# Ancient Cheese        29.0         31.0   52.0
# GOLF                  13.0         12.0   62.0
# WAR                   37.0         16.0   76.0
# Pepperman              0.0          0.0  100.0
# Pizzascape            30.0         38.0  112.0
# Tutorial               0.0          0.0  136.0
# John Gutter           91.0         59.0  360.0

# %%
g = grph.plot_minute_histogram(scp.DATA_PATH / "PT_leaderboard_Any_2023-10-28.parquet", "Any%", minute_cutoff=85)

# %%
from time import sleep
import sys

for i in range(21):
    sys.stdout.write('\r')
    # the exact output you're looking for:
    sys.stdout.write("[%-20s] %d%%" % ('='*i, 5*i))
    sys.stdout.flush()
    sleep(0.25)

# %%
get_user_name("v81v7558")

# %%
all_runs['status_judgment'] = all_runs['status'].apply(lambda x: x['status'])

# %%
all_runs.groupby(['status_judgment']).count()
# Out:
#                    id  weblink  game  level  category  videos  comment  \
# status_judgment
# new                38       38    38     26        38      38       21
# rejected          512      512   512    268       512     511      346
# verified         4114     4114  4114   2580      4114    4114     3264
#
#                  status  date  submitted  times  system  splits  links  \
# status_judgment
# new                  38    38         38     38      38       0     38
# rejected            512   512        512    512     512      12    512
# verified           4114  4114       4114   4114    4114      48   4114
#
#                  player  is_rat  primary_t  is_il   pid
# status_judgment
# new                  38      38         38     38    38
# rejected            512     512        512    512   512
# verified           4114    4114       4114   4114  4099

# %%
no_rejections = all_runs.loc[all_runs['status_judgment'] != 'rejected']

# %%
no_rejections.info()

# %%
x = scp.query_api("games", arg_str=scp.build_arg_str({'name': 'Pizza_Tower'}))
# Out:
# Got 5 results

# %%
x[0].json()
# Out:
# {'data': [{'id': 'o6gnpox1',
#    'names': {'international': 'Pizza Tower',
#     'japanese': None,
#     'twitch': 'Pizza Tower'},
#    'boostReceived': 9,
#    'boostDistinctDonors': 4,
#    'abbreviation': 'pizza_tower',
#    'weblink': 'https://www.speedrun.com/pizza_tower',
#    'discord': 'https://discord.gg/N9NREB6',
#    'released': 2023,
#    'release-date': '2023-01-26',
#    'ruleset': {'show-milliseconds': True,
#     'require-verification': True,
#     'require-video': True,
#     'run-times': ['realtime'],
#     'default-time': 'realtime',
#     'emulators-allowed': True},
#    'romhack': False,
#    'gametypes': [],
#    'platforms': ['8gej2n93', 'w89rqoel'],
#    'regions': [],
#    'genres': ['qdnqkn8k'],
#    'engines': ['2n5keo5d'],
#    'developers': ['veg30kz0'],
#    'publishers': ['vr8okm6g'],
#    'moderators': {'v8lzke7x': 'super-moderator',
#     'v81v7558': 'super-moderator',
#     'zx70eo0j': 'super-moderator',
#     '68wrdwzj': 'moderator',
#     'v8ld9rrj': 'super-moderator',
#     '48gpl1p8': 'super-moderator',
#     'y8dql19j': 'super-moderator',
#     '5j53ozgx': 'super-moderator',
#     'xkoyp9k8': 'moderator',
#     'j922yyv8': 'super-moderator',
#     'xko3z398': 'super-moderator',
#     'x7q7vor8': 'super-moderator',
#     'jn9wkldx': 'super-moderator',
#     'jp6dkw28': 'super-moderator',
#     '8q62zddj': 'super-moderator',
#     'jnpelz28': 'super-moderator',
#     'j5qz5knj': 'super-moderator'},
#    'created': '2023-01-30T19:41:51Z',
#    'assets': {'logo': {'uri': 'https://www.speedrun.com/static/theme/mwzp3k58/logo?v=17fcfc2'},
#     'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/o6gnpox1/cover?v=3661982'},
#     'cover-small': {'uri': 'https://www.speedrun.com/static/game/o6gnpox1/cover?v=3661982'},
#     'cover-medium': {'uri': 'https://www.speedrun.com/static/game/o6gnpox1/cover?v=3661982'},
#     'cover-large': {'uri': 'https://www.speedrun.com/static/game/o6gnpox1/cover?v=3661982'},
#     'icon': {'uri': 'https://www.speedrun.com/static/theme/mwzp3k58/favicon?v=7e2a900'},
#     'trophy-1st': {'uri': 'https://www.speedrun.com/static/theme/mwzp3k58/1st?v=6f6c2f2'},
#     'trophy-2nd': {'uri': 'https://www.speedrun.com/static/theme/mwzp3k58/2nd?v=2510fda'},
#     'trophy-3rd': {'uri': 'https://www.speedrun.com/static/theme/mwzp3k58/3rd?v=2e75461'},
#     'trophy-4th': {'uri': None},
#     'background': {'uri': 'https://www.speedrun.com/static/theme/mwzp3k58/background?v=9383885'},
#     'foreground': {'uri': None}},
#    'links': [{'rel': 'self',
#      'uri': 'https://www.speedrun.com/api/v1/games/o6gnpox1'},
#     {'rel': 'runs',
#      'uri': 'https://www.speedrun.com/api/v1/runs?game=o6gnpox1'},
#     {'rel': 'levels',
#      'uri': 'https://www.speedrun.com/api/v1/games/o6gnpox1/levels'},
#     {'rel': 'categories',
#      'uri': 'https://www.speedrun.com/api/v1/games/o6gnpox1/categories'},
#     {'rel': 'variables',
#      'uri': 'https://www.speedrun.com/api/v1/games/o6gnpox1/variables'},
#     {'rel': 'records',
#      'uri': 'https://www.speedrun.com/api/v1/games/o6gnpox1/records'},
#     {'rel': 'series',
#      'uri': 'https://www.speedrun.com/api/v1/series/yr4gon12'},
#     {'rel': 'derived-games',
#      'uri': 'https://www.speedrun.com/api/v1/games/o6gnpox1/derived-games'},
#     {'rel': 'romhacks',
#      'uri': 'https://www.speedrun.com/api/v1/games/o6gnpox1/derived-games'},
#     {'rel': 'leaderboard',
#      'uri': 'https://www.speedrun.com/api/v1/leaderboards/o6gnpox1/category/7kj7xg4k'}]},
#   {'id': 'j1ne2ex1',
#    'names': {'international': 'Pizza Tower (Demos)',
#     'japanese': None,
#     'twitch': 'Pizza Tower'},
#    'boostReceived': 0,
#    'boostDistinctDonors': 0,
#    'abbreviation': 'pizza_tower_demo',
#    'weblink': 'https://www.speedrun.com/pizza_tower_demo',
#    'discord': 'https://discord.gg/hA5t7st',
#    'released': 2018,
#    'release-date': '2018-10-01',
#    'ruleset': {'show-milliseconds': True,
#     'require-verification': True,
#     'require-video': True,
#     'run-times': ['realtime'],
#     'default-time': 'realtime',
#     'emulators-allowed': True},
#    'romhack': True,
#    'gametypes': ['x3n6vme4'],
#    'platforms': ['8gej2n93'],
#    'regions': [],
#    'genres': ['qdnqkn8k'],
#    'engines': [],
#    'developers': ['veg30kz0'],
#    'publishers': ['vr8okm6g'],
#    'moderators': {'v8ld9rrj': 'super-moderator',
#     'y8dql19j': 'super-moderator',
#     '5j53ozgx': 'super-moderator',
#     'x7q7vor8': 'super-moderator'},
#    'created': '2019-04-30T06:34:25Z',
#    'assets': {'logo': {'uri': 'https://www.speedrun.com/static/theme/zr2lkx84/logo?v=17fcfc2'},
#     'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/j1ne2ex1/cover?v=78e4826'},
#     'cover-small': {'uri': 'https://www.speedrun.com/static/game/j1ne2ex1/cover?v=78e4826'},
#     'cover-medium': {'uri': 'https://www.speedrun.com/static/game/j1ne2ex1/cover?v=78e4826'},
#     'cover-large': {'uri': 'https://www.speedrun.com/static/game/j1ne2ex1/cover?v=78e4826'},
#     'icon': {'uri': 'https://www.speedrun.com/static/theme/zr2lkx84/favicon?v=3f93db7'},
#     'trophy-1st': {'uri': 'https://www.speedrun.com/images/1st.png'},
#     'trophy-2nd': {'uri': 'https://www.speedrun.com/images/2nd.png'},
#     'trophy-3rd': {'uri': 'https://www.speedrun.com/images/3rd.png'},
#     'trophy-4th': {'uri': None},
#     'background': {'uri': 'https://www.speedrun.com/static/theme/zr2lkx84/background?v=01d428c'},
#     'foreground': {'uri': None}},
#    'links': [{'rel': 'self',
#      'uri': 'https://www.speedrun.com/api/v1/games/j1ne2ex1'},
#     {'rel': 'runs',
#      'uri': 'https://www.speedrun.com/api/v1/runs?game=j1ne2ex1'},
#     {'rel': 'levels',
#      'uri': 'https://www.speedrun.com/api/v1/games/j1ne2ex1/levels'},
#     {'rel': 'categories',
#      'uri': 'https://www.speedrun.com/api/v1/games/j1ne2ex1/categories'},
#     {'rel': 'variables',
#      'uri': 'https://www.speedrun.com/api/v1/games/j1ne2ex1/variables'},
#     {'rel': 'records',
#      'uri': 'https://www.speedrun.com/api/v1/games/j1ne2ex1/records'},
#     {'rel': 'series',
#      'uri': 'https://www.speedrun.com/api/v1/series/yr4gon12'},
#     {'rel': 'base-game',
#      'uri': 'https://www.speedrun.com/api/v1/games/o6gnpox1'},
#     {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/o6gnpox1'},
#     {'rel': 'derived-games',
#      'uri': 'https://www.speedrun.com/api/v1/games/j1ne2ex1/derived-games'},
#     {'rel': 'romhacks',
#      'uri': 'https://www.speedrun.com/api/v1/games/j1ne2ex1/derived-games'},
#     {'rel': 'leaderboard',
#      'uri': 'https://www.speedrun.com/api/v1/leaderboards/j1ne2ex1/category/n2yoqled'}]},
#   {'id': '2689ee91',
#    'names': {'international': 'Pizza Tower: Snake Demo',
#     'japanese': None,
#     'twitch': 'Pizza Tower: Snake Edition'},
#    'boostReceived': 0,
#    'boostDistinctDonors': 0,
#    'abbreviation': 'Pizza_Tower_Snake_Edition',
#    'weblink': 'https://www.speedrun.com/Pizza_Tower_Snake_Edition',
#    'discord': None,
#    'released': 2023,
#    'release-date': '2023-04-04',
#    'ruleset': {'show-milliseconds': True,
#     'require-verification': True,
#     'require-video': True,
#     'run-times': ['realtime'],
#     'default-time': 'realtime',
#     'emulators-allowed': True},
#    'romhack': False,
#    'gametypes': [],
#    'platforms': ['8gej2n93'],
#    'regions': [],
#    'genres': [],
#    'engines': [],
#    'developers': [],
#    'publishers': [],
#    'moderators': {'xz2m9lex': 'super-moderator', 'j2q09n6j': 'moderator'},
#    'created': '2023-07-28T18:15:45Z',
#    'assets': {'logo': {'uri': 'https://www.speedrun.com/images/logo.png'},
#     'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/2689ee91/cover?v=be5aaf0'},
#     'cover-small': {'uri': 'https://www.speedrun.com/static/game/2689ee91/cover?v=be5aaf0'},
#     'cover-medium': {'uri': 'https://www.speedrun.com/static/game/2689ee91/cover?v=be5aaf0'},
#     'cover-large': {'uri': 'https://www.speedrun.com/static/game/2689ee91/cover?v=be5aaf0'},
#     'icon': {'uri': 'https://www.speedrun.com/images/1st.png'},
#     'trophy-1st': {'uri': 'https://www.speedrun.com/images/1st.png'},
#     'trophy-2nd': {'uri': 'https://www.speedrun.com/images/2nd.png'},
#     'trophy-3rd': {'uri': 'https://www.speedrun.com/images/3rd.png'},
#     'trophy-4th': {'uri': None},
#     'background': {'uri': None},
#     'foreground': {'uri': None}},
#    'links': [{'rel': 'self',
#      'uri': 'https://www.speedrun.com/api/v1/games/2689ee91'},
#     {'rel': 'runs',
#      'uri': 'https://www.speedrun.com/api/v1/runs?game=2689ee91'},
#     {'rel': 'levels',
#      'uri': 'https://www.speedrun.com/api/v1/games/2689ee91/levels'},
#     {'rel': 'categories',
#      'uri': 'https://www.speedrun.com/api/v1/games/2689ee91/categories'},
#     {'rel': 'variables',
#      'uri': 'https://www.speedrun.com/api/v1/games/2689ee91/variables'},
#     {'rel': 'records',
#      'uri': 'https://www.speedrun.com/api/v1/games/2689ee91/records'},
#     {'rel': 'series',
#      'uri': 'https://www.speedrun.com/api/v1/series/yr4gon12'},
#     {'rel': 'derived-games',
#      'uri': 'https://www.speedrun.com/api/v1/games/2689ee91/derived-games'},
#     {'rel': 'romhacks',
#      'uri': 'https://www.speedrun.com/api/v1/games/2689ee91/derived-games'},
#     {'rel': 'leaderboard',
#      'uri': 'https://www.speedrun.com/api/v1/leaderboards/2689ee91/category/5dwe4oed'}]},
#   {'id': 'pdv99xv1',
#    'names': {'international': 'Pizza Tower Category Extensions',
#     'japanese': None,
#     'twitch': 'Pizza Tower Category Extensions'},
#    'boostReceived': 0,
#    'boostDistinctDonors': 0,
#    'abbreviation': 'Pizza_Tower_CE',
#    'weblink': 'https://www.speedrun.com/Pizza_Tower_CE',
#    'discord': 'https://discord.gg/N9NREB6',
#    'released': 2023,
#    'release-date': '2023-01-26',
#    'ruleset': {'show-milliseconds': True,
#     'require-verification': True,
#     'require-video': True,
#     'run-times': ['realtime', 'ingame'],
#     'default-time': 'ingame',
#     'emulators-allowed': True},
#    'romhack': False,
#    'gametypes': [],
#    'platforms': ['8gej2n93', 'w89rqoel'],
#    'regions': [],
#    'genres': [],
#    'engines': [],
#    'developers': [],
#    'publishers': [],
#    'moderators': {'v8lzke7x': 'super-moderator',
#     'v81v7558': 'super-moderator',
#     'zx70eo0j': 'moderator',
#     '68wrdwzj': 'moderator',
#     'v8ld9rrj': 'super-moderator',
#     '48gpl1p8': 'super-moderator',
#     'y8dql19j': 'super-moderator',
#     '5j53ozgx': 'super-moderator',
#     'xkoyp9k8': 'moderator',
#     'j922yyv8': 'super-moderator',
#     'xko3z398': 'super-moderator',
#     'x7q7vor8': 'super-moderator',
#     'jn9wkldx': 'super-moderator',
#     'jp6dkw28': 'super-moderator',
#     '8q62zddj': 'super-moderator',
#     'jnpelz28': 'super-moderator',
#     'j5qz5knj': 'super-moderator'},
#    'created': '2023-10-25T19:16:30Z',
#    'assets': {'logo': {'uri': 'https://www.speedrun.com/static/theme/zr23dlo8/logo?v=17fcfc2'},
#     'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/pdv99xv1/cover?v=e38d598'},
#     'cover-small': {'uri': 'https://www.speedrun.com/static/game/pdv99xv1/cover?v=e38d598'},
#     'cover-medium': {'uri': 'https://www.speedrun.com/static/game/pdv99xv1/cover?v=e38d598'},
#     'cover-large': {'uri': 'https://www.speedrun.com/static/game/pdv99xv1/cover?v=e38d598'},
#     'icon': {'uri': 'https://www.speedrun.com/static/theme/zr23dlo8/favicon?v=e6aa0dd'},
#     'trophy-1st': {'uri': 'https://www.speedrun.com/static/theme/zr23dlo8/1st?v=f220b01'},
#     'trophy-2nd': {'uri': 'https://www.speedrun.com/static/theme/zr23dlo8/2nd?v=f4871f9'},
#     'trophy-3rd': {'uri': 'https://www.speedrun.com/static/theme/zr23dlo8/3rd?v=2875dee'},
#     'trophy-4th': {'uri': None},
#     'background': {'uri': 'https://www.speedrun.com/static/theme/zr23dlo8/background?v=61c84dc'},
#     'foreground': {'uri': None}},
#    'links': [{'rel': 'self',
#      'uri': 'https://www.speedrun.com/api/v1/games/pdv99xv1'},
#     {'rel': 'runs',
#      'uri': 'https://www.speedrun.com/api/v1/runs?game=pdv99xv1'},
#     {'rel': 'levels',
#      'uri': 'https://www.speedrun.com/api/v1/games/pdv99xv1/levels'},
#     {'rel': 'categories',
#      'uri': 'https://www.speedrun.com/api/v1/games/pdv99xv1/categories'},
#     {'rel': 'variables',
#      'uri': 'https://www.speedrun.com/api/v1/games/pdv99xv1/variables'},
#     {'rel': 'records',
#      'uri': 'https://www.speedrun.com/api/v1/games/pdv99xv1/records'},
#     {'rel': 'series',
#      'uri': 'https://www.speedrun.com/api/v1/series/yr4gon12'},
#     {'rel': 'derived-games',
#      'uri': 'https://www.speedrun.com/api/v1/games/pdv99xv1/derived-games'},
#     {'rel': 'romhacks',
#      'uri': 'https://www.speedrun.com/api/v1/games/pdv99xv1/derived-games'},
#     {'rel': 'leaderboard',
#      'uri': 'https://www.speedrun.com/api/v1/leaderboards/pdv99xv1/category/824o563d'}]},
#   {'id': 'm1zk97m1',
#    'names': {'international': 'Pizza Tower: Create Your Own Pizza',
#     'japanese': None,
#     'twitch': ''},
#    'boostReceived': 0,
#    'boostDistinctDonors': 0,
#    'abbreviation': 'pizza_tower_create_your_own_pizza',
#    'weblink': 'https://www.speedrun.com/pizza_tower_create_your_own_pizza',
#    'discord': '',
#    'released': 2023,
#    'release-date': '2023-05-14',
#    'ruleset': {'show-milliseconds': True,
#     'require-verification': True,
#     'require-video': True,
#     'run-times': ['realtime', 'ingame'],
#     'default-time': 'ingame',
#     'emulators-allowed': True},
#    'romhack': True,
#    'gametypes': ['lyn97m9o', 'j8138myw'],
#    'platforms': ['8gej2n93', 'w89rqoel'],
#    'regions': [],
#    'genres': ['qdnqkn8k', '7d5ov32w'],
#    'engines': [],
#    'developers': ['neldml62'],
#    'publishers': ['l6m1xj69'],
#    'moderators': {'j407d6w8': 'super-moderator'},
#    'created': '2023-06-14T22:22:43Z',
#    'assets': {'logo': {'uri': 'https://www.speedrun.com/static/theme/or3mym38/logo?v=17fcfc2'},
#     'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/m1zk97m1/cover?v=31d57d3'},
#     'cover-small': {'uri': 'https://www.speedrun.com/static/game/m1zk97m1/cover?v=31d57d3'},
#     'cover-medium': {'uri': 'https://www.speedrun.com/static/game/m1zk97m1/cover?v=31d57d3'},
#     'cover-large': {'uri': 'https://www.speedrun.com/static/game/m1zk97m1/cover?v=31d57d3'},
#     'icon': {'uri': 'https://www.speedrun.com/static/theme/or3mym38/favicon?v=fa2f02a'},
#     'trophy-1st': {'uri': 'https://www.speedrun.com/images/1st.png'},
#     'trophy-2nd': {'uri': 'https://www.speedrun.com/images/2nd.png'},
#     'trophy-3rd': {'uri': 'https://www.speedrun.com/images/3rd.png'},
#     'trophy-4th': {'uri': None},
#     'background': {'uri': 'https://www.speedrun.com/static/theme/or3mym38/background?v=0475f05'},
#     'foreground': {'uri': None}},
#    'links': [{'rel': 'self',
#      'uri': 'https://www.speedrun.com/api/v1/games/m1zk97m1'},
#     {'rel': 'runs',
#      'uri': 'https://www.speedrun.com/api/v1/runs?game=m1zk97m1'},
#     {'rel': 'levels',
#      'uri': 'https://www.speedrun.com/api/v1/games/m1zk97m1/levels'},
#     {'rel': 'categories',
#      'uri': 'https://www.speedrun.com/api/v1/games/m1zk97m1/categories'},
#     {'rel': 'variables',
#      'uri': 'https://www.speedrun.com/api/v1/games/m1zk97m1/variables'},
#     {'rel': 'records',
#      'uri': 'https://www.speedrun.com/api/v1/games/m1zk97m1/records'},
#     {'rel': 'series',
#      'uri': 'https://www.speedrun.com/api/v1/series/yr4gon12'},
#     {'rel': 'base-game',
#      'uri': 'https://www.speedrun.com/api/v1/games/o6gnpox1'},
#     {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/o6gnpox1'},
#     {'rel': 'derived-games',
#      'uri': 'https://www.speedrun.com/api/v1/games/m1zk97m1/derived-games'},
#     {'rel': 'romhacks',
#      'uri': 'https://www.speedrun.com/api/v1/games/m1zk97m1/derived-games'},
#     {'rel': 'leaderboard',
#      'uri': 'https://www.speedrun.com/api/v1/leaderboards/m1zk97m1/category/02qwyn92'}]}],
#  'pagination': {'offset': 0, 'max': 20, 'size': 5, 'links': []}}

# %%
all_rejects = all_runs.loc[all_runs['status_judgment'] == 'rejected']

# %%
all_rejects.groupby(['level'])['id'].count()
# Out:
# level
# 29vqlnxd      5
# 592y8e6w     16
# 5d7geqed      2
# 5wk3n4x9      3
# 69z1qe4w      4
# ewplz44d      4
# gdrz86k9      7
# kwj28419      3
# ldyo5k79      3
# n935717w      3
# n93rnlr9     18
# n93rnzr9     13
# nwl8y4gd      1
# o9xjzr7d      7
# owore43w      2
# rdnylx69     12
# rdqe34gd      7
# rw6zl56d      4
# xd0826j9      5
# xd1n3lyw      5
# xd4lyg89     26
# y9mnr40d      3
# yweojx49      4
# z98v637w      1
# z98xz41d      4
# z98xz51d    106
# Name: id, dtype: int64

# %%
all_rejects = pd.merge(all_rejects, lvl, left_on='level', right_on='id', how='left', suffixes=('_runs', '_levels'))
all_rejects = pd.merge(all_rejects, cat, left_on='category', right_on='id', how='left', suffixes=(None, '_categories'))

# %%
all_rejects.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 512 entries, 0 to 511
# Data columns (total 34 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_runs           512 non-null    object
#  1   weblink_runs      512 non-null    object
#  2   game              512 non-null    object
#  3   level             268 non-null    object
#  4   category          512 non-null    object
#  5   videos            511 non-null    object
#  6   comment           346 non-null    object
#  7   status            512 non-null    object
#  8   date              512 non-null    datetime64[ns]
#  9   submitted         512 non-null    object
#  10  times             512 non-null    object
#  11  system            512 non-null    object
#  12  splits            12 non-null     object
#  13  links_runs        512 non-null    object
#  14  player            512 non-null    object
#  15  is_rat            512 non-null    bool
#  16  primary_t         512 non-null    float64
#  17  is_il             512 non-null    bool
#  18  pid               512 non-null    object
#  19  status_judgment   512 non-null    object
#  20  id_levels         268 non-null    object
#  21  name              268 non-null    object
#  22  weblink_levels    268 non-null    object
#  23  rules             61 non-null     object
#  24  links_levels      268 non-null    object
#  25  short_name        268 non-null    object
#  26  id                512 non-null    object
#  27  name_categories   512 non-null    object
#  28  weblink           512 non-null    object
#  29  type              512 non-null    object
#  30  rules_categories  512 non-null    object
#  31  players           512 non-null    object
#  32  miscellaneous     512 non-null    bool
#  33  links             512 non-null    object
# dtypes: bool(3), datetime64[ns](1), float64(1), object(29)
# memory usage: 125.6+ KB

# %%
all_rejects.groupby(['name_categories'])['id'].count()
# Out:
# name_categories
# 100%            33
# 101%             3
# All Toppins     24
# Any%           398
# Snotty%         15
# True Ending     39
# Name: id, dtype: int64

# %%
all_rejects.count()
# Out:
# id_runs             512
# weblink_runs        512
# game                512
# level               268
# category            512
# videos              511
# comment             346
# status              512
# date                512
# submitted           512
# times               512
# system              512
# splits               12
# links_runs          512
# player              512
# is_rat              512
# primary_t           512
# is_il               512
# pid                 512
# status_judgment     512
# id_levels           268
# name                268
# weblink_levels      268
# rules                61
# links_levels        268
# short_name          268
# id                  512
# name_categories     512
# weblink             512
# type                512
# rules_categories    512
# players             512
# miscellaneous       512
# links               512
# dtype: int64

# %%
all_runs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4664 entries, 0 to 4663
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               4664 non-null   object
#  1   weblink          4664 non-null   object
#  2   game             4664 non-null   object
#  3   level            2874 non-null   object
#  4   category         4664 non-null   object
#  5   videos           4663 non-null   object
#  6   comment          3631 non-null   object
#  7   status           4664 non-null   object
#  8   date             4664 non-null   datetime64[ns]
#  9   submitted        4664 non-null   object
#  10  times            4664 non-null   object
#  11  system           4664 non-null   object
#  12  splits           60 non-null     object
#  13  links            4664 non-null   object
#  14  player           4664 non-null   object
#  15  is_rat           4664 non-null   bool
#  16  primary_t        4664 non-null   float64
#  17  is_il            4664 non-null   bool
#  18  pid              4649 non-null   object
#  19  status_judgment  4664 non-null   object
# dtypes: bool(2), datetime64[ns](1), float64(1), object(16)
# memory usage: 665.1+ KB

# %%
all_runs.head()
# Out:
#          id                                            weblink      game  \
# 0  y2jpvw5z  https://www.speedrun.com/pizza_tower/run/y2jpvw5z  o6gnpox1
# 1  z0np6q9m  https://www.speedrun.com/pizza_tower/run/z0np6q9m  o6gnpox1
# 2  y808vpxm  https://www.speedrun.com/pizza_tower/run/y808vpxm  o6gnpox1
# 3  znjpoxvm  https://www.speedrun.com/pizza_tower/run/znjpoxvm  o6gnpox1
# 4  yln7oxxz  https://www.speedrun.com/pizza_tower/run/yln7oxxz  o6gnpox1
#
#       level  category                                             videos  \
# 0      None  7kj7xg4k  {'links': [{'uri': 'https://www.youtube.com/wa...
# 1  z98xz51d  zdn76z9k  {'links': [{'uri': 'https://www.youtube.com/wa...
# 2  rdqe34gd  zdn76z9k  {'links': [{'uri': 'https://www.youtube.com/wa...
# 3  z98xz51d  zdn76z9k  {'links': [{'uri': 'https://youtu.be/6jFle5erp...
# 4  69z1qe4w  zdn76z9k  {'links': [{'uri': 'https://www.youtube.com/wa...
#
#                                              comment  \
# 0  Any% run with lots of errors, especially with ...
# 1  reupload since the leaderboard changed lol, st...
# 2  reupload due to new board, still going strong ...
# 3                                               None
# 4                                               None
#
#                                               status       date  \
# 0  {'status': 'verified', 'examiner': 'y8dql19j',... 2023-01-29
# 1  {'status': 'verified', 'examiner': '5j53ozgx',... 2023-01-30
# 2  {'status': 'verified', 'examiner': '5j53ozgx',... 2023-01-30
# 3  {'status': 'verified', 'examiner': '5j53ozgx',... 2023-01-30
# 4  {'status': 'verified', 'examiner': '5j53ozgx',... 2023-01-28
#
#               submitted                                              times  \
# 0  2023-01-30T21:29:03Z  {'primary': 'PT1H33M10.700S', 'primary_t': 559...
# 1  2023-01-30T21:29:04Z  {'primary': 'PT2M34S', 'primary_t': 154, 'real...
# 2  2023-01-30T21:30:29Z  {'primary': 'PT3M59.170S', 'primary_t': 239.17...
# 3  2023-01-30T21:31:12Z  {'primary': 'PT1M25.590S', 'primary_t': 85.59,...
# 4  2023-01-30T21:31:33Z  {'primary': 'PT2M45.290S', 'primary_t': 165.29...
#
#                                               system splits  \
# 0  {'platform': '8gej2n93', 'emulated': False, 'r...   None
# 1  {'platform': '8gej2n93', 'emulated': False, 'r...   None
# 2  {'platform': '8gej2n93', 'emulated': False, 'r...   None
# 3  {'platform': '8gej2n93', 'emulated': False, 'r...   None
# 4  {'platform': '8gej2n93', 'emulated': False, 'r...   None
#
#                                                links  \
# 0  [{'rel': 'self', 'uri': 'https://www.speedrun....
# 1  [{'rel': 'self', 'uri': 'https://www.speedrun....
# 2  [{'rel': 'self', 'uri': 'https://www.speedrun....
# 3  [{'rel': 'self', 'uri': 'https://www.speedrun....
# 4  [{'rel': 'self', 'uri': 'https://www.speedrun....
#
#                                               player  is_rat  primary_t  \
# 0  {'rel': 'user', 'id': '7j41kldj', 'uri': 'http...   False    5590.70
# 1  {'rel': 'user', 'id': '8r7l0mdj', 'uri': 'http...   False     154.00
# 2  {'rel': 'user', 'id': '8r7l0mdj', 'uri': 'http...   False     239.17
# 3  {'rel': 'user', 'id': 'jnz6r71j', 'uri': 'http...   False      85.59
# 4  {'rel': 'user', 'id': '18qq10d8', 'uri': 'http...   False     165.29
#
#    is_il       pid status_judgment
# 0  False  7j41kldj        verified
# 1   True  8r7l0mdj        verified
# 2   True  8r7l0mdj        verified
# 3   True  jnz6r71j        verified
# 4   True  18qq10d8        verified

# %%
all_runs[['id','weblink','game']]
# Out:
#             id                                            weblink      game
# 0     y2jpvw5z  https://www.speedrun.com/pizza_tower/run/y2jpvw5z  o6gnpox1
# 1     z0np6q9m  https://www.speedrun.com/pizza_tower/run/z0np6q9m  o6gnpox1
# 2     y808vpxm  https://www.speedrun.com/pizza_tower/run/y808vpxm  o6gnpox1
# 3     znjpoxvm  https://www.speedrun.com/pizza_tower/run/znjpoxvm  o6gnpox1
# 4     yln7oxxz  https://www.speedrun.com/pizza_tower/run/yln7oxxz  o6gnpox1
# ...        ...                                                ...       ...
# 4659  y9k3nvvz  https://www.speedrun.com/pizza_tower/run/y9k3nvvz  o6gnpox1
# 4660  y6q96qpz  https://www.speedrun.com/pizza_tower/run/y6q96qpz  o6gnpox1
# 4661  yd2ere0m  https://www.speedrun.com/pizza_tower/run/yd2ere0m  o6gnpox1
# 4662  mr2n1n7y  https://www.speedrun.com/pizza_tower/run/mr2n1n7y  o6gnpox1
# 4663  y8kedeny  https://www.speedrun.com/pizza_tower/run/y8kedeny  o6gnpox1
#
# [4664 rows x 3 columns]

# %%
joined_runs = grph.join_all_data()
joined_runs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4137 entries, 0 to 4663
# Data columns (total 35 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_runs           4137 non-null   object
#  1   weblink_runs      4137 non-null   object
#  2   game              4137 non-null   object
#  3   level             2591 non-null   object
#  4   category          4137 non-null   object
#  5   videos            4137 non-null   object
#  6   comment           3285 non-null   object
#  7   status            4137 non-null   object
#  8   date              4137 non-null   datetime64[ns]
#  9   submitted         4137 non-null   object
#  10  times             4137 non-null   object
#  11  system            4137 non-null   object
#  12  splits            48 non-null     object
#  13  links_runs        4137 non-null   object
#  14  player            4137 non-null   object
#  15  is_rat            4137 non-null   bool
#  16  primary_t         4137 non-null   float64
#  17  is_il             4137 non-null   bool
#  18  pid               4137 non-null   object
#  19  status_judgment   4137 non-null   object
#  20  id_levels         2591 non-null   object
#  21  name              2591 non-null   object
#  22  weblink_levels    2591 non-null   object
#  23  rules             409 non-null    object
#  24  links_levels      2591 non-null   object
#  25  short_name        2591 non-null   object
#  26  id                4137 non-null   object
#  27  name_categories   4137 non-null   object
#  28  weblink           4137 non-null   object
#  29  type              4137 non-null   object
#  30  rules_categories  4137 non-null   object
#  31  players           4137 non-null   object
#  32  miscellaneous     4137 non-null   bool
#  33  links             4137 non-null   object
#  34  Categories        4137 non-null   object
# dtypes: bool(3), datetime64[ns](1), float64(1), object(30)
# memory usage: 1.1+ MB

# %%
joined_runs.head()
# Out:
#     id_runs                                       weblink_runs      game  \
# 0  y2jpvw5z  https://www.speedrun.com/pizza_tower/run/y2jpvw5z  o6gnpox1
# 1  z0np6q9m  https://www.speedrun.com/pizza_tower/run/z0np6q9m  o6gnpox1
# 2  y808vpxm  https://www.speedrun.com/pizza_tower/run/y808vpxm  o6gnpox1
# 3  znjpoxvm  https://www.speedrun.com/pizza_tower/run/znjpoxvm  o6gnpox1
# 4  yln7oxxz  https://www.speedrun.com/pizza_tower/run/yln7oxxz  o6gnpox1
#
#       level  category                                             videos  \
# 0      None  7kj7xg4k  {'links': [{'uri': 'https://www.youtube.com/wa...
# 1  z98xz51d  zdn76z9k  {'links': [{'uri': 'https://www.youtube.com/wa...
# 2  rdqe34gd  zdn76z9k  {'links': [{'uri': 'https://www.youtube.com/wa...
# 3  z98xz51d  zdn76z9k  {'links': [{'uri': 'https://youtu.be/6jFle5erp...
# 4  69z1qe4w  zdn76z9k  {'links': [{'uri': 'https://www.youtube.com/wa...
#
#                                              comment  \
# 0  Any% run with lots of errors, especially with ...
# 1  reupload since the leaderboard changed lol, st...
# 2  reupload due to new board, still going strong ...
# 3                                               None
# 4                                               None
#
#                                               status       date  \
# 0  {'examiner': 'y8dql19j', 'reason': None, 'stat... 2023-01-29
# 1  {'examiner': '5j53ozgx', 'reason': None, 'stat... 2023-01-30
# 2  {'examiner': '5j53ozgx', 'reason': None, 'stat... 2023-01-30
# 3  {'examiner': '5j53ozgx', 'reason': None, 'stat... 2023-01-30
# 4  {'examiner': '5j53ozgx', 'reason': None, 'stat... 2023-01-28
#
#               submitted  ...   short_name        id name_categories  \
# 0  2023-01-30T21:29:03Z  ...          NaN  7kj7xg4k            Any%
# 1  2023-01-30T21:29:04Z  ...  John Gutter  zdn76z9k            Any%
# 2  2023-01-30T21:30:29Z  ...         GOLF  zdn76z9k            Any%
# 3  2023-01-30T21:31:12Z  ...  John Gutter  zdn76z9k            Any%
# 4  2023-01-30T21:31:33Z  ...     Fun Farm  zdn76z9k            Any%
#
#                                     weblink       type  \
# 0  https://www.speedrun.com/pizza_tower#Any   per-game
# 1      https://www.speedrun.com/pizza_tower  per-level
# 2      https://www.speedrun.com/pizza_tower  per-level
# 3      https://www.speedrun.com/pizza_tower  per-level
# 4      https://www.speedrun.com/pizza_tower  per-level
#
#                                     rules_categories  \
# 0  * Runs must show File Select at the beginning ...
# 1  - **Time starts on spawning into the level and...
# 2  - **Time starts on spawning into the level and...
# 3  - **Time starts on spawning into the level and...
# 4  - **Time starts on spawning into the level and...
#
#                            players  miscellaneous  \
# 0  {'type': 'exactly', 'value': 1}          False
# 1  {'type': 'exactly', 'value': 1}          False
# 2  {'type': 'exactly', 'value': 1}          False
# 3  {'type': 'exactly', 'value': 1}          False
# 4  {'type': 'exactly', 'value': 1}          False
#
#                                                links Categories
# 0  [{'rel': 'self', 'uri': 'https://www.speedrun....       Any%
# 1  [{'rel': 'self', 'uri': 'https://www.speedrun....       Any%
# 2  [{'rel': 'self', 'uri': 'https://www.speedrun....       Any%
# 3  [{'rel': 'self', 'uri': 'https://www.speedrun....       Any%
# 4  [{'rel': 'self', 'uri': 'https://www.speedrun....       Any%
#
# [5 rows x 35 columns]

# %%
joined_runs[['links_runs', 'player', 'pid', 'Categories', 'name_categories']].head()
# Out:
#                                           links_runs  \
# 0  [{'rel': 'self', 'uri': 'https://www.speedrun....
# 1  [{'rel': 'self', 'uri': 'https://www.speedrun....
# 2  [{'rel': 'self', 'uri': 'https://www.speedrun....
# 3  [{'rel': 'self', 'uri': 'https://www.speedrun....
# 4  [{'rel': 'self', 'uri': 'https://www.speedrun....
#
#                                               player       pid Categories  \
# 0  {'id': '7j41kldj', 'name': None, 'rel': 'user'...  7j41kldj       Any%
# 1  {'id': '8r7l0mdj', 'name': None, 'rel': 'user'...  8r7l0mdj       Any%
# 2  {'id': '8r7l0mdj', 'name': None, 'rel': 'user'...  8r7l0mdj       Any%
# 3  {'id': 'jnz6r71j', 'name': None, 'rel': 'user'...  jnz6r71j       Any%
# 4  {'id': '18qq10d8', 'name': None, 'rel': 'user'...  18qq10d8       Any%
#
#   name_categories
# 0            Any%
# 1            Any%
# 2            Any%
# 3            Any%
# 4            Any%

# %%
get_user_name('v81v7558')
# Out:
# 'Vicas'

# %%
get_user_name('7j41kldj')
# Out:
# 'UncleJeol'

# %%
from utils import USER_PICKLE
len(USER_PICKLE)
# Out:
# 1269

# %%
len(USER_PICKLE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 len(USER_PICKLE)
#
# NameError: name 'USER_PICKLE' is not defined

# %%
all_runs['runner_name'].describe()
# Out:
# count         4691
# unique        1270
# top       psyk2642
# freq           122
# Name: runner_name, dtype: object

# %%
all_runs[all_runs['runner_name'] == "Guest"]
# Out:
#             id                                            weblink      game  \
# 6     z0np68om  https://www.speedrun.com/pizza_tower/run/z0np68om  o6gnpox1
# 7     znjpo9vm  https://www.speedrun.com/pizza_tower/run/znjpo9vm  o6gnpox1
# 8     ywv30wnz  https://www.speedrun.com/pizza_tower/run/ywv30wnz  o6gnpox1
# 9     yln7opxz  https://www.speedrun.com/pizza_tower/run/yln7opxz  o6gnpox1
# 11    mkvk7wly  https://www.speedrun.com/pizza_tower/run/mkvk7wly  o6gnpox1
# 12    zxn760km  https://www.speedrun.com/pizza_tower/run/zxn760km  o6gnpox1
# 187   z1qgl1jy  https://www.speedrun.com/pizza_tower/run/z1qgl1jy  o6gnpox1
# 188   mkvd093y  https://www.speedrun.com/pizza_tower/run/mkvd093y  o6gnpox1
# 189   m72x0p5z  https://www.speedrun.com/pizza_tower/run/m72x0p5z  o6gnpox1
# 190   mrorl84m  https://www.speedrun.com/pizza_tower/run/mrorl84m  o6gnpox1
# 191   z5exp1dz  https://www.speedrun.com/pizza_tower/run/z5exp1dz  o6gnpox1
# 192   m3lxqo6m  https://www.speedrun.com/pizza_tower/run/m3lxqo6m  o6gnpox1
# 528   ydgjk20y  https://www.speedrun.com/pizza_tower/run/ydgjk20y  o6gnpox1
# 4507  mr211e4y  https://www.speedrun.com/pizza_tower/run/mr211e4y  o6gnpox1
# 4508  zxwggkgm  https://www.speedrun.com/pizza_tower/run/zxwggkgm  o6gnpox1
#
#          level  category                                             videos  \
# 6     n93rnlr9  q259yjvk  {'links': [{'uri': 'https://youtu.be/F0kehT9au...
# 7     xd4lyg89  q259yjvk  {'links': [{'uri': 'https://youtu.be/F0kehT9au...
# 8     xd0826j9  q259yjvk  {'links': [{'uri': 'https://youtu.be/F0kehT9au...
# 9     rw6zl56d  q259yjvk  {'links': [{'uri': 'https://youtu.be/F0kehT9au...
# 11    n93rnzr9  q259yjvk  {'links': [{'uri': 'https://youtu.be/F0kehT9au...
# 12    z98xz41d  q259yjvk  {'links': [{'uri': 'https://youtu.be/F0kehT9au...
# 187   n93rnlr9  zdnpwwxk  {'links': [{'uri': 'https://youtu.be/F0kehT9au...
# 188   xd4lyg89  zdnpwwxk  {'links': [{'uri': 'https://youtu.be/F0kehT9au...
# 189   xd0826j9  zdnpwwxk  {'links': [{'uri': 'https://youtu.be/F0kehT9au...
# 190   rw6zl56d  zdnpwwxk  {'links': [{'uri': 'https://youtu.be/F0kehT9au...
# 191   z98xz41d  zdnpwwxk  {'links': [{'uri': 'https://youtu.be/F0kehT9au...
# 192   n93rnzr9  zdnpwwxk  {'links': [{'uri': 'https://youtu.be/F0kehT9au...
# 528   29vqlnxd  zdnpwwxk  {'links': [{'uri': 'https://youtu.be/F0kehT9au...
# 4507  n935717w  zdnpwwxk  {'links': [{'uri': 'https://youtu.be/F0kehT9au...
# 4508  z98v637w  zdnpwwxk  {'links': [{'uri': 'https://youtu.be/F0kehT9au...
#
#      comment                                             status       date  \
# 6       None  {'status': 'verified', 'examiner': '5j53ozgx',... 2023-01-30
# 7       None  {'status': 'verified', 'examiner': '5j53ozgx',... 2023-01-30
# 8       None  {'status': 'verified', 'examiner': '5j53ozgx',... 2023-01-30
# 9       None  {'status': 'verified', 'examiner': '5j53ozgx',... 2023-01-30
# 11      None  {'status': 'verified', 'examiner': '5j53ozgx',... 2023-01-30
# 12      None  {'status': 'verified', 'examiner': '5j53ozgx',... 2023-01-30
# 187     None  {'status': 'verified', 'examiner': '5j53ozgx',... 2023-02-06
# 188     None  {'status': 'verified', 'examiner': '5j53ozgx',... 2023-02-06
# 189     None  {'status': 'verified', 'examiner': '5j53ozgx',... 2023-02-06
# 190     None  {'status': 'verified', 'examiner': '5j53ozgx',... 2023-02-06
# 191     None  {'status': 'verified', 'examiner': '5j53ozgx',... 2023-02-06
# 192     None  {'status': 'verified', 'examiner': '5j53ozgx',... 2023-02-06
# 528     None  {'status': 'verified', 'examiner': '5j53ozgx',... 2023-02-20
# 4507    None  {'status': 'verified', 'examiner': '5j53ozgx',... 2023-10-24
# 4508    None  {'status': 'verified', 'examiner': '5j53ozgx',... 2023-10-24
#
#                  submitted  ...  \
# 6     2023-01-30T21:39:02Z  ...
# 7     2023-01-30T21:40:19Z  ...
# 8     2023-01-30T21:40:37Z  ...
# 9     2023-01-30T21:40:56Z  ...
# 11    2023-01-30T21:43:06Z  ...
# 12    2023-01-30T21:43:28Z  ...
# 187   2023-02-06T18:58:08Z  ...
# 188   2023-02-06T18:58:46Z  ...
# 189   2023-02-06T18:59:02Z  ...
# 190   2023-02-06T18:59:18Z  ...
# 191   2023-02-06T18:59:38Z  ...
# 192   2023-02-06T18:59:52Z  ...
# 528   2023-02-20T21:24:55Z  ...
# 4507  2023-10-24T00:29:36Z  ...
# 4508  2023-10-24T00:30:14Z  ...
#
#                                                  system splits  \
# 6     {'platform': '8gej2n93', 'emulated': False, 'r...   None
# 7     {'platform': '8gej2n93', 'emulated': False, 'r...   None
# 8     {'platform': '8gej2n93', 'emulated': False, 'r...   None
# 9     {'platform': '8gej2n93', 'emulated': False, 'r...   None
# 11    {'platform': '8gej2n93', 'emulated': False, 'r...   None
# 12    {'platform': '8gej2n93', 'emulated': False, 'r...   None
# 187   {'platform': '8gej2n93', 'emulated': False, 'r...   None
# 188   {'platform': '8gej2n93', 'emulated': False, 'r...   None
# 189   {'platform': '8gej2n93', 'emulated': False, 'r...   None
# 190   {'platform': '8gej2n93', 'emulated': False, 'r...   None
# 191   {'platform': '8gej2n93', 'emulated': False, 'r...   None
# 192   {'platform': '8gej2n93', 'emulated': False, 'r...   None
# 528   {'platform': '8gej2n93', 'emulated': False, 'r...   None
# 4507  {'platform': '8gej2n93', 'emulated': False, 'r...   None
# 4508  {'platform': '8gej2n93', 'emulated': False, 'r...   None
#
#                                                   links  \
# 6     [{'rel': 'self', 'uri': 'https://www.speedrun....
# 7     [{'rel': 'self', 'uri': 'https://www.speedrun....
# 8     [{'rel': 'self', 'uri': 'https://www.speedrun....
# 9     [{'rel': 'self', 'uri': 'https://www.speedrun....
# 11    [{'rel': 'self', 'uri': 'https://www.speedrun....
# 12    [{'rel': 'self', 'uri': 'https://www.speedrun....
# 187   [{'rel': 'self', 'uri': 'https://www.speedrun....
# 188   [{'rel': 'self', 'uri': 'https://www.speedrun....
# 189   [{'rel': 'self', 'uri': 'https://www.speedrun....
# 190   [{'rel': 'self', 'uri': 'https://www.speedrun....
# 191   [{'rel': 'self', 'uri': 'https://www.speedrun....
# 192   [{'rel': 'self', 'uri': 'https://www.speedrun....
# 528   [{'rel': 'self', 'uri': 'https://www.speedrun....
# 4507  [{'rel': 'self', 'uri': 'https://www.speedrun....
# 4508  [{'rel': 'self', 'uri': 'https://www.speedrun....
#
#                                                  player is_rat  primary_t  \
# 6     {'rel': 'guest', 'name': 'Stupid Rat', 'uri': ...   True      0.001
# 7     {'rel': 'guest', 'name': 'Stupid Rat', 'uri': ...   True      0.001
# 8     {'rel': 'guest', 'name': 'Stupid Rat', 'uri': ...   True      0.001
# 9     {'rel': 'guest', 'name': 'Stupid Rat', 'uri': ...   True      0.001
# 11    {'rel': 'guest', 'name': 'Stupid Rat', 'uri': ...   True      0.001
# 12    {'rel': 'guest', 'name': 'Stupid Rat', 'uri': ...   True      0.001
# 187   {'rel': 'guest', 'name': 'Stupid Rat', 'uri': ...   True      0.001
# 188   {'rel': 'guest', 'name': 'Stupid Rat', 'uri': ...   True      0.001
# 189   {'rel': 'guest', 'name': 'Stupid Rat', 'uri': ...   True      0.001
# 190   {'rel': 'guest', 'name': 'Stupid Rat', 'uri': ...   True      0.001
# 191   {'rel': 'guest', 'name': 'Stupid Rat', 'uri': ...   True      0.001
# 192   {'rel': 'guest', 'name': 'Stupid Rat', 'uri': ...   True      0.001
# 528   {'rel': 'guest', 'name': 'Stupid Rat', 'uri': ...   True      0.001
# 4507  {'rel': 'guest', 'name': 'Stupid Rat', 'uri': ...   True      0.001
# 4508  {'rel': 'guest', 'name': 'Stupid Rat', 'uri': ...   True      0.001
#
#       is_il   pid status_judgment runner_name
# 6      True  None        verified       Guest
# 7      True  None        verified       Guest
# 8      True  None        verified       Guest
# 9      True  None        verified       Guest
# 11     True  None        verified       Guest
# 12     True  None        verified       Guest
# 187    True  None        verified       Guest
# 188    True  None        verified       Guest
# 189    True  None        verified       Guest
# 190    True  None        verified       Guest
# 191    True  None        verified       Guest
# 192    True  None        verified       Guest
# 528    True  None        verified       Guest
# 4507   True  None        verified       Guest
# 4508   True  None        verified       Guest
#
# [15 rows x 21 columns]

# %%
x = requests.get(f"{SRC_API_URL}/games?name=Pizza Tower")
x.json()
# Out:
# {'data': [{'id': 'o6gnpox1',
#    'names': {'international': 'Pizza Tower',
#     'japanese': None,
#     'twitch': 'Pizza Tower'},
#    'boostReceived': 9,
#    'boostDistinctDonors': 4,
#    'abbreviation': 'pizza_tower',
#    'weblink': 'https://www.speedrun.com/pizza_tower',
#    'discord': 'https://discord.gg/N9NREB6',
#    'released': 2023,
#    'release-date': '2023-01-26',
#    'ruleset': {'show-milliseconds': True,
#     'require-verification': True,
#     'require-video': True,
#     'run-times': ['realtime'],
#     'default-time': 'realtime',
#     'emulators-allowed': True},
#    'romhack': False,
#    'gametypes': [],
#    'platforms': ['8gej2n93', 'w89rqoel'],
#    'regions': [],
#    'genres': ['qdnqkn8k'],
#    'engines': ['2n5keo5d'],
#    'developers': ['veg30kz0'],
#    'publishers': ['vr8okm6g'],
#    'moderators': {'v8lzke7x': 'super-moderator',
#     'v81v7558': 'super-moderator',
#     'zx70eo0j': 'super-moderator',
#     '68wrdwzj': 'moderator',
#     'v8ld9rrj': 'super-moderator',
#     '48gpl1p8': 'super-moderator',
#     'y8dql19j': 'super-moderator',
#     '5j53ozgx': 'super-moderator',
#     'xkoyp9k8': 'moderator',
#     'j922yyv8': 'super-moderator',
#     'xko3z398': 'super-moderator',
#     'x7q7vor8': 'super-moderator',
#     'jn9wkldx': 'super-moderator',
#     'jp6dkw28': 'super-moderator',
#     '8q62zddj': 'super-moderator',
#     'jnpelz28': 'super-moderator',
#     'j5qz5knj': 'super-moderator'},
#    'created': '2023-01-30T19:41:51Z',
#    'assets': {'logo': {'uri': 'https://www.speedrun.com/static/theme/mwzp3k58/logo?v=17fcfc2'},
#     'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/o6gnpox1/cover?v=3661982'},
#     'cover-small': {'uri': 'https://www.speedrun.com/static/game/o6gnpox1/cover?v=3661982'},
#     'cover-medium': {'uri': 'https://www.speedrun.com/static/game/o6gnpox1/cover?v=3661982'},
#     'cover-large': {'uri': 'https://www.speedrun.com/static/game/o6gnpox1/cover?v=3661982'},
#     'icon': {'uri': 'https://www.speedrun.com/static/theme/mwzp3k58/favicon?v=7e2a900'},
#     'trophy-1st': {'uri': 'https://www.speedrun.com/static/theme/mwzp3k58/1st?v=6f6c2f2'},
#     'trophy-2nd': {'uri': 'https://www.speedrun.com/static/theme/mwzp3k58/2nd?v=2510fda'},
#     'trophy-3rd': {'uri': 'https://www.speedrun.com/static/theme/mwzp3k58/3rd?v=2e75461'},
#     'trophy-4th': {'uri': None},
#     'background': {'uri': 'https://www.speedrun.com/static/theme/mwzp3k58/background?v=9383885'},
#     'foreground': {'uri': None}},
#    'links': [{'rel': 'self',
#      'uri': 'https://www.speedrun.com/api/v1/games/o6gnpox1'},
#     {'rel': 'runs',
#      'uri': 'https://www.speedrun.com/api/v1/runs?game=o6gnpox1'},
#     {'rel': 'levels',
#      'uri': 'https://www.speedrun.com/api/v1/games/o6gnpox1/levels'},
#     {'rel': 'categories',
#      'uri': 'https://www.speedrun.com/api/v1/games/o6gnpox1/categories'},
#     {'rel': 'variables',
#      'uri': 'https://www.speedrun.com/api/v1/games/o6gnpox1/variables'},
#     {'rel': 'records',
#      'uri': 'https://www.speedrun.com/api/v1/games/o6gnpox1/records'},
#     {'rel': 'series',
#      'uri': 'https://www.speedrun.com/api/v1/series/yr4gon12'},
#     {'rel': 'derived-games',
#      'uri': 'https://www.speedrun.com/api/v1/games/o6gnpox1/derived-games'},
#     {'rel': 'romhacks',
#      'uri': 'https://www.speedrun.com/api/v1/games/o6gnpox1/derived-games'},
#     {'rel': 'leaderboard',
#      'uri': 'https://www.speedrun.com/api/v1/leaderboards/o6gnpox1/category/7kj7xg4k'}]},
#   {'id': 'j1ne2ex1',
#    'names': {'international': 'Pizza Tower (Demos)',
#     'japanese': None,
#     'twitch': 'Pizza Tower'},
#    'boostReceived': 0,
#    'boostDistinctDonors': 0,
#    'abbreviation': 'pizza_tower_demo',
#    'weblink': 'https://www.speedrun.com/pizza_tower_demo',
#    'discord': 'https://discord.gg/hA5t7st',
#    'released': 2018,
#    'release-date': '2018-10-01',
#    'ruleset': {'show-milliseconds': True,
#     'require-verification': True,
#     'require-video': True,
#     'run-times': ['realtime'],
#     'default-time': 'realtime',
#     'emulators-allowed': True},
#    'romhack': True,
#    'gametypes': ['x3n6vme4'],
#    'platforms': ['8gej2n93'],
#    'regions': [],
#    'genres': ['qdnqkn8k'],
#    'engines': [],
#    'developers': ['veg30kz0'],
#    'publishers': ['vr8okm6g'],
#    'moderators': {'v8ld9rrj': 'super-moderator',
#     'y8dql19j': 'super-moderator',
#     '5j53ozgx': 'super-moderator',
#     'x7q7vor8': 'super-moderator'},
#    'created': '2019-04-30T06:34:25Z',
#    'assets': {'logo': {'uri': 'https://www.speedrun.com/static/theme/zr2lkx84/logo?v=17fcfc2'},
#     'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/j1ne2ex1/cover?v=78e4826'},
#     'cover-small': {'uri': 'https://www.speedrun.com/static/game/j1ne2ex1/cover?v=78e4826'},
#     'cover-medium': {'uri': 'https://www.speedrun.com/static/game/j1ne2ex1/cover?v=78e4826'},
#     'cover-large': {'uri': 'https://www.speedrun.com/static/game/j1ne2ex1/cover?v=78e4826'},
#     'icon': {'uri': 'https://www.speedrun.com/static/theme/zr2lkx84/favicon?v=3f93db7'},
#     'trophy-1st': {'uri': 'https://www.speedrun.com/images/1st.png'},
#     'trophy-2nd': {'uri': 'https://www.speedrun.com/images/2nd.png'},
#     'trophy-3rd': {'uri': 'https://www.speedrun.com/images/3rd.png'},
#     'trophy-4th': {'uri': None},
#     'background': {'uri': 'https://www.speedrun.com/static/theme/zr2lkx84/background?v=01d428c'},
#     'foreground': {'uri': None}},
#    'links': [{'rel': 'self',
#      'uri': 'https://www.speedrun.com/api/v1/games/j1ne2ex1'},
#     {'rel': 'runs',
#      'uri': 'https://www.speedrun.com/api/v1/runs?game=j1ne2ex1'},
#     {'rel': 'levels',
#      'uri': 'https://www.speedrun.com/api/v1/games/j1ne2ex1/levels'},
#     {'rel': 'categories',
#      'uri': 'https://www.speedrun.com/api/v1/games/j1ne2ex1/categories'},
#     {'rel': 'variables',
#      'uri': 'https://www.speedrun.com/api/v1/games/j1ne2ex1/variables'},
#     {'rel': 'records',
#      'uri': 'https://www.speedrun.com/api/v1/games/j1ne2ex1/records'},
#     {'rel': 'series',
#      'uri': 'https://www.speedrun.com/api/v1/series/yr4gon12'},
#     {'rel': 'base-game',
#      'uri': 'https://www.speedrun.com/api/v1/games/o6gnpox1'},
#     {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/o6gnpox1'},
#     {'rel': 'derived-games',
#      'uri': 'https://www.speedrun.com/api/v1/games/j1ne2ex1/derived-games'},
#     {'rel': 'romhacks',
#      'uri': 'https://www.speedrun.com/api/v1/games/j1ne2ex1/derived-games'},
#     {'rel': 'leaderboard',
#      'uri': 'https://www.speedrun.com/api/v1/leaderboards/j1ne2ex1/category/n2yoqled'}]},
#   {'id': '2689ee91',
#    'names': {'international': 'Pizza Tower: Snake Demo',
#     'japanese': None,
#     'twitch': 'Pizza Tower: Snake Edition'},
#    'boostReceived': 0,
#    'boostDistinctDonors': 0,
#    'abbreviation': 'Pizza_Tower_Snake_Edition',
#    'weblink': 'https://www.speedrun.com/Pizza_Tower_Snake_Edition',
#    'discord': None,
#    'released': 2023,
#    'release-date': '2023-04-04',
#    'ruleset': {'show-milliseconds': True,
#     'require-verification': True,
#     'require-video': True,
#     'run-times': ['realtime'],
#     'default-time': 'realtime',
#     'emulators-allowed': True},
#    'romhack': False,
#    'gametypes': [],
#    'platforms': ['8gej2n93'],
#    'regions': [],
#    'genres': [],
#    'engines': [],
#    'developers': [],
#    'publishers': [],
#    'moderators': {'xz2m9lex': 'super-moderator', 'j2q09n6j': 'moderator'},
#    'created': '2023-07-28T18:15:45Z',
#    'assets': {'logo': {'uri': 'https://www.speedrun.com/images/logo.png'},
#     'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/2689ee91/cover?v=be5aaf0'},
#     'cover-small': {'uri': 'https://www.speedrun.com/static/game/2689ee91/cover?v=be5aaf0'},
#     'cover-medium': {'uri': 'https://www.speedrun.com/static/game/2689ee91/cover?v=be5aaf0'},
#     'cover-large': {'uri': 'https://www.speedrun.com/static/game/2689ee91/cover?v=be5aaf0'},
#     'icon': {'uri': 'https://www.speedrun.com/images/1st.png'},
#     'trophy-1st': {'uri': 'https://www.speedrun.com/images/1st.png'},
#     'trophy-2nd': {'uri': 'https://www.speedrun.com/images/2nd.png'},
#     'trophy-3rd': {'uri': 'https://www.speedrun.com/images/3rd.png'},
#     'trophy-4th': {'uri': None},
#     'background': {'uri': None},
#     'foreground': {'uri': None}},
#    'links': [{'rel': 'self',
#      'uri': 'https://www.speedrun.com/api/v1/games/2689ee91'},
#     {'rel': 'runs',
#      'uri': 'https://www.speedrun.com/api/v1/runs?game=2689ee91'},
#     {'rel': 'levels',
#      'uri': 'https://www.speedrun.com/api/v1/games/2689ee91/levels'},
#     {'rel': 'categories',
#      'uri': 'https://www.speedrun.com/api/v1/games/2689ee91/categories'},
#     {'rel': 'variables',
#      'uri': 'https://www.speedrun.com/api/v1/games/2689ee91/variables'},
#     {'rel': 'records',
#      'uri': 'https://www.speedrun.com/api/v1/games/2689ee91/records'},
#     {'rel': 'series',
#      'uri': 'https://www.speedrun.com/api/v1/series/yr4gon12'},
#     {'rel': 'derived-games',
#      'uri': 'https://www.speedrun.com/api/v1/games/2689ee91/derived-games'},
#     {'rel': 'romhacks',
#      'uri': 'https://www.speedrun.com/api/v1/games/2689ee91/derived-games'},
#     {'rel': 'leaderboard',
#      'uri': 'https://www.speedrun.com/api/v1/leaderboards/2689ee91/category/5dwe4oed'}]},
#   {'id': 'pdv99xv1',
#    'names': {'international': 'Pizza Tower Category Extensions',
#     'japanese': None,
#     'twitch': 'Pizza Tower Category Extensions'},
#    'boostReceived': 0,
#    'boostDistinctDonors': 0,
#    'abbreviation': 'Pizza_Tower_CE',
#    'weblink': 'https://www.speedrun.com/Pizza_Tower_CE',
#    'discord': 'https://discord.gg/N9NREB6',
#    'released': 2023,
#    'release-date': '2023-01-26',
#    'ruleset': {'show-milliseconds': True,
#     'require-verification': True,
#     'require-video': True,
#     'run-times': ['realtime', 'ingame'],
#     'default-time': 'ingame',
#     'emulators-allowed': True},
#    'romhack': True,
#    'gametypes': ['53no817x'],
#    'platforms': ['8gej2n93', 'w89rqoel'],
#    'regions': [],
#    'genres': [],
#    'engines': [],
#    'developers': [],
#    'publishers': [],
#    'moderators': {'v8lzke7x': 'super-moderator',
#     'v81v7558': 'super-moderator',
#     'zx70eo0j': 'moderator',
#     '68wrdwzj': 'moderator',
#     'v8ld9rrj': 'super-moderator',
#     '48gpl1p8': 'super-moderator',
#     'y8dql19j': 'super-moderator',
#     '5j53ozgx': 'super-moderator',
#     'xkoyp9k8': 'moderator',
#     'j922yyv8': 'super-moderator',
#     'xko3z398': 'super-moderator',
#     'x7q7vor8': 'super-moderator',
#     'jn9wkldx': 'super-moderator',
#     'jp6dkw28': 'super-moderator',
#     '8q62zddj': 'super-moderator',
#     'jnpelz28': 'super-moderator',
#     'j5qz5knj': 'super-moderator'},
#    'created': '2023-10-25T19:16:30Z',
#    'assets': {'logo': {'uri': 'https://www.speedrun.com/static/theme/zr23dlo8/logo?v=17fcfc2'},
#     'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/pdv99xv1/cover?v=e38d598'},
#     'cover-small': {'uri': 'https://www.speedrun.com/static/game/pdv99xv1/cover?v=e38d598'},
#     'cover-medium': {'uri': 'https://www.speedrun.com/static/game/pdv99xv1/cover?v=e38d598'},
#     'cover-large': {'uri': 'https://www.speedrun.com/static/game/pdv99xv1/cover?v=e38d598'},
#     'icon': {'uri': 'https://www.speedrun.com/static/theme/zr23dlo8/favicon?v=e6aa0dd'},
#     'trophy-1st': {'uri': 'https://www.speedrun.com/static/theme/zr23dlo8/1st?v=f220b01'},
#     'trophy-2nd': {'uri': 'https://www.speedrun.com/static/theme/zr23dlo8/2nd?v=f4871f9'},
#     'trophy-3rd': {'uri': 'https://www.speedrun.com/static/theme/zr23dlo8/3rd?v=2875dee'},
#     'trophy-4th': {'uri': None},
#     'background': {'uri': 'https://www.speedrun.com/static/theme/zr23dlo8/background?v=61c84dc'},
#     'foreground': {'uri': None}},
#    'links': [{'rel': 'self',
#      'uri': 'https://www.speedrun.com/api/v1/games/pdv99xv1'},
#     {'rel': 'runs',
#      'uri': 'https://www.speedrun.com/api/v1/runs?game=pdv99xv1'},
#     {'rel': 'levels',
#      'uri': 'https://www.speedrun.com/api/v1/games/pdv99xv1/levels'},
#     {'rel': 'categories',
#      'uri': 'https://www.speedrun.com/api/v1/games/pdv99xv1/categories'},
#     {'rel': 'variables',
#      'uri': 'https://www.speedrun.com/api/v1/games/pdv99xv1/variables'},
#     {'rel': 'records',
#      'uri': 'https://www.speedrun.com/api/v1/games/pdv99xv1/records'},
#     {'rel': 'series',
#      'uri': 'https://www.speedrun.com/api/v1/series/yr4gon12'},
#     {'rel': 'base-game',
#      'uri': 'https://www.speedrun.com/api/v1/games/o6gnpox1'},
#     {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/o6gnpox1'},
#     {'rel': 'derived-games',
#      'uri': 'https://www.speedrun.com/api/v1/games/pdv99xv1/derived-games'},
#     {'rel': 'romhacks',
#      'uri': 'https://www.speedrun.com/api/v1/games/pdv99xv1/derived-games'},
#     {'rel': 'leaderboard',
#      'uri': 'https://www.speedrun.com/api/v1/leaderboards/pdv99xv1/category/824o563d'}]},
#   {'id': 'm1zk97m1',
#    'names': {'international': 'Pizza Tower: Create Your Own Pizza',
#     'japanese': None,
#     'twitch': ''},
#    'boostReceived': 0,
#    'boostDistinctDonors': 0,
#    'abbreviation': 'pizza_tower_create_your_own_pizza',
#    'weblink': 'https://www.speedrun.com/pizza_tower_create_your_own_pizza',
#    'discord': '',
#    'released': 2023,
#    'release-date': '2023-05-14',
#    'ruleset': {'show-milliseconds': True,
#     'require-verification': True,
#     'require-video': True,
#     'run-times': ['realtime', 'ingame'],
#     'default-time': 'ingame',
#     'emulators-allowed': True},
#    'romhack': True,
#    'gametypes': ['lyn97m9o', 'j8138myw'],
#    'platforms': ['8gej2n93', 'w89rqoel'],
#    'regions': [],
#    'genres': ['qdnqkn8k', '7d5ov32w'],
#    'engines': [],
#    'developers': ['neldml62'],
#    'publishers': ['l6m1xj69'],
#    'moderators': {'j407d6w8': 'super-moderator'},
#    'created': '2023-06-14T22:22:43Z',
#    'assets': {'logo': {'uri': 'https://www.speedrun.com/static/theme/or3mym38/logo?v=17fcfc2'},
#     'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/m1zk97m1/cover?v=31d57d3'},
#     'cover-small': {'uri': 'https://www.speedrun.com/static/game/m1zk97m1/cover?v=31d57d3'},
#     'cover-medium': {'uri': 'https://www.speedrun.com/static/game/m1zk97m1/cover?v=31d57d3'},
#     'cover-large': {'uri': 'https://www.speedrun.com/static/game/m1zk97m1/cover?v=31d57d3'},
#     'icon': {'uri': 'https://www.speedrun.com/static/theme/or3mym38/favicon?v=fa2f02a'},
#     'trophy-1st': {'uri': 'https://www.speedrun.com/images/1st.png'},
#     'trophy-2nd': {'uri': 'https://www.speedrun.com/images/2nd.png'},
#     'trophy-3rd': {'uri': 'https://www.speedrun.com/images/3rd.png'},
#     'trophy-4th': {'uri': None},
#     'background': {'uri': 'https://www.speedrun.com/static/theme/or3mym38/background?v=0475f05'},
#     'foreground': {'uri': None}},
#    'links': [{'rel': 'self',
#      'uri': 'https://www.speedrun.com/api/v1/games/m1zk97m1'},
#     {'rel': 'runs',
#      'uri': 'https://www.speedrun.com/api/v1/runs?game=m1zk97m1'},
#     {'rel': 'levels',
#      'uri': 'https://www.speedrun.com/api/v1/games/m1zk97m1/levels'},
#     {'rel': 'categories',
#      'uri': 'https://www.speedrun.com/api/v1/games/m1zk97m1/categories'},
#     {'rel': 'variables',
#      'uri': 'https://www.speedrun.com/api/v1/games/m1zk97m1/variables'},
#     {'rel': 'records',
#      'uri': 'https://www.speedrun.com/api/v1/games/m1zk97m1/records'},
#     {'rel': 'series',
#      'uri': 'https://www.speedrun.com/api/v1/series/yr4gon12'},
#     {'rel': 'base-game',
#      'uri': 'https://www.speedrun.com/api/v1/games/o6gnpox1'},
#     {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/o6gnpox1'},
#     {'rel': 'derived-games',
#      'uri': 'https://www.speedrun.com/api/v1/games/m1zk97m1/derived-games'},
#     {'rel': 'romhacks',
#      'uri': 'https://www.speedrun.com/api/v1/games/m1zk97m1/derived-games'},
#     {'rel': 'leaderboard',
#      'uri': 'https://www.speedrun.com/api/v1/leaderboards/m1zk97m1/category/02qwyn92'}]}],
#  'pagination': {'offset': 0, 'max': 20, 'size': 5, 'links': []}}
